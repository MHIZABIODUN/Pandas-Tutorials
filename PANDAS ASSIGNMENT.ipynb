# %%
import pandas as pd

# %%
Tatanic_df = pd.read_csv('./tested.csv')

# %%
Tatanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
Tatanic_df[['Name', 'Survived']]
# Out:
#                                              Name  Survived
# 0                                Kelly, Mr. James         0
# 1                Wilkes, Mrs. James (Ellen Needs)         1
# 2                       Myles, Mr. Thomas Francis         0
# 3                                Wirz, Mr. Albert         0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)         1
# ..                                            ...       ...
# 413                            Spector, Mr. Woolf         0
# 414                  Oliva y Ocana, Dona. Fermina         1
# 415                  Saether, Mr. Simon Sivertsen         0
# 416                           Ware, Mr. Frederick         0
# 417                      Peter, Master. Michael J         0
#
# [418 rows x 2 columns]

# %%
Tatanic_df.iloc[0:5]
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
Tatanic_df.iloc[:, [1, 3]]
# Out:
#      Survived                                          Name
# 0           0                              Kelly, Mr. James
# 1           1              Wilkes, Mrs. James (Ellen Needs)
# 2           0                     Myles, Mr. Thomas Francis
# 3           0                              Wirz, Mr. Albert
# 4           1  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..        ...                                           ...
# 413         0                            Spector, Mr. Woolf
# 414         1                  Oliva y Ocana, Dona. Fermina
# 415         0                  Saether, Mr. Simon Sivertsen
# 416         0                           Ware, Mr. Frederick
# 417         0                      Peter, Master. Michael J
#
# [418 rows x 2 columns]

# %%
Tatanic_df[(Tatanic_df['Age'] > 30)]
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 11           903         0       1
# 13           905         0       2
# ..           ...       ...     ...
# 404         1296         0       1
# 407         1299         0       1
# 411         1303         1       1
# 414         1306         1       1
# 415         1307         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                                   Kelly, Mr. James    male  34.5      0
# 1                   Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2                          Myles, Mr. Thomas Francis    male  62.0      0
# 11                        Jones, Mr. Charles Cresson    male  46.0      0
# 13                              Howard, Mr. Benjamin    male  63.0      1
# ..                                               ...     ...   ...    ...
# ...

# %%
Tatanic_df[(Tatanic_df['Age'] > 30) & (Tatanic_df['Pclass'] == 1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 11           903         0       1
# 14           906         1       1
# 20           912         0       1
# 24           916         1       1
# 28           920         0       1
# ..           ...       ...     ...
# 397         1289         1       1
# 404         1296         0       1
# 407         1299         0       1
# 411         1303         1       1
# 414         1306         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 11                          Jones, Mr. Charles Cresson    male  46.0      0
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 20                              Rothschild, Mr. Martin    male  55.0      1
# 24     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# 28                             Brady, Mr. John Bertram    male  41.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
Tatanic_df['Fare'] = Tatanic_df['Fare'] + 10

# %%
Tatanic_df['Age'] = Tatanic_df['Age'] - 10

# %%
Tatanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  24.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  37.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  52.0      0      0
# 3                                Wirz, Mr. Albert    male  17.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  12.0      1      1
# ...

# %%
Tatanic_df['FamilySize'] = Tatanic_df['SibSp'] + 1

# %%
Tatanic_df['FamilySize'] = Tatanic_df['Parch'] + 1

# %%
Tatanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  24.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  37.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  52.0      0      0
# 3                                Wirz, Mr. Albert    male  17.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  12.0      1      1
# ...
