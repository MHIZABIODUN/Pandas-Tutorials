# %%
import pandas as pd

# %%
mens_perfume = pd.read_csv('./ebay_mens_perfume.csv')

# %%
mens_perfume.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              999 non-null    object
#  1   title              1000 non-null   object
#  2   type               997 non-null    object
#  3   price              1000 non-null   float64
#  4   priceWithCurrency  1000 non-null   object
#  5   available          889 non-null    float64
#  6   availableText      997 non-null    object
#  7   sold               994 non-null    float64
#  8   lastUpdated        947 non-null    object
#  9   itemLocation       1000 non-null   object
# dtypes: float64(3), object(7)
# memory usage: 78.3+ KB

# %%
mens_perfume.groupby(['brand', 'title'])['price'].sum()
# Out:
# brand                title
# 2nd To None          6 For $19.95 MEN(M) WOMEN(W) & UNISEX(U) Body Oil Fragrances 10 ml Roll On Pure       6.65
# AS PHOTOS            New Carolina-Herrera 212 NYC Men Eau De Toilette 3.4 oz/ 100 ml                      34.68
# AS PICTURE SHOWN     Silver Mountain Water Eau De Parfum 3.3 / 3.4 OZ 100 ML Spray For men New In Box    125.99
# AS SHOW              A-v-entus Eau de Parfum 3.3 oz 100ML Millesime EDP Col-ogne for Men New In Box      109.99
#                      A-ventu-s for Men 3.3 OZ./ 100 ML.Eau de Parfum Spray for Men New Sealed Box         99.49
#                                                                                                           ...
# king of kings        King of Kings Royal Blue Parfum 3.4 oz for Men is a wonderful men's fragrance        79.99
# rue21                Rue 21 CJ Black Cologne Spray  1.7 fl. Oz  New Without Box                           25.00
# ...

# %%
mens_perfume['available'].max()
# Out:
# 842.0

# %%
brand_price = mens_perfume.groupby(['brand', 'title', 'type'])['price'].sum()

# %%
# sorted = brand_price.sort_value()

# %%
sorted
# Out:
# <function sorted(iterable, /, *, key=None, reverse=False)>

# %%
brand_price = mens_perfume.groupby(['brand', 'title', 'type'])['price'].sum().sort_values(ascending=False)

# %%
brand_price
# Out:
# brand                  title                                                                             type
# Creed                  Aventus by Creed, 3.3 oz Millesime EDP Spray for Men                              Eau De Parfum                       259.09
# Bvlgari                Bvlgari Le Gemme Tygar 3.4oz Men's Eau de Parfum                                  Eau de Parfum                       250.00
# Dolce&Gabbana          Dolce & Gabbana The One Luminous Night 3.3/3.4 oz Eau De Parfum 100 ml Spray Men  Eau de Parfum                       239.99
# Creed                  Aventus Cologne by Creed, 3.3 oz Millesime EDP Spray for Men                      Eau De Parfum                       212.89
# Roja                   Elysium by Roja Parfums, 3.4 oz Parfum Cologne Spray for Men                      Gift Sets                           202.95
# ...

# %%
brand_price[:10]
# Out:
# brand            title                                                                             type
# Creed            Aventus by Creed, 3.3 oz Millesime EDP Spray for Men                              Eau De Parfum      259.09
# Bvlgari          Bvlgari Le Gemme Tygar 3.4oz Men's Eau de Parfum                                  Eau de Parfum      250.00
# Dolce&Gabbana    Dolce & Gabbana The One Luminous Night 3.3/3.4 oz Eau De Parfum 100 ml Spray Men  Eau de Parfum      239.99
# Creed            Aventus Cologne by Creed, 3.3 oz Millesime EDP Spray for Men                      Eau De Parfum      212.89
# Roja             Elysium by Roja Parfums, 3.4 oz Parfum Cologne Spray for Men                      Gift Sets          202.95
# Giorgio Armani   Acqua Di Gio Absolu Giorgio Armani EDP 125 ML / 4.2 Fl Oz Men Perfume             Eau de Parfum      192.00
# As picture show  New In Box Eau De Parfum Aventus 3.3 /OZ 100 ML Spray For men                     Eau de Parfum      189.99
# ...

# %%
mens_perfume['title'].value_counts()
# Out:
# title
# YSL Yves Saint Laurent Y Eau de Perfume Spray Cologne For Men 3.3 oz 100ML          4
# Hawas for him Eau De Parfum By Rasasi 100ml 3.4 FL OZ NEW                           4
# SEALED NEW CUPID 2.0 HYPNOSIS MEN’S PHEROMONE COLOGNE 1.7 OZ MEET MORE HOT WOMEN    3
# New 2024 Sexy Cologne Cupid Hypnosis Long Lasting Pheromone Perfume for Men         3
# 1/2PCS 50ml Men's Pheromone-Cupid Infused Perfume- Hypnosis Cologne Fragrances      3
#                                                                                    ..
# PS by Paul Sebastian Cologne for Men 8 / 8.0 oz Brand New In Box                    1
# Ralph Lauren Polo Black 4.2 oz / 125 ml Eau De Toilette Spray For Men Brand New!    1
# HALLOWEEN MAN J. Del Pozo cologne edt 4.2 oz NEW IN BOX                             1
# SpiceBomb Extreme Made Stronger With Pheromones For Super Hot Sexual Attraction!    1
# Beyond Paradise by Estee Lauder for Men Cologne Spray EDT 0.5 oz , New              1
# ...

# %%
mens_perfume[ mens_perfume['title'] == 'YSL Yves Saint Laurent Y Eau de Perfume Spray Cologne For Men 3.3 oz 100ML']
# Out:
#          brand                                              title  \
# 104   As Shown  YSL Yves Saint Laurent Y Eau de Perfume Spray ...
# 210  Unbranded  YSL Yves Saint Laurent Y Eau de Perfume Spray ...
# 223  fragrance  YSL Yves Saint Laurent Y Eau de Perfume Spray ...
# 448    As Show  YSL Yves Saint Laurent Y Eau de Perfume Spray ...
#
#               type  price priceWithCurrency  available          availableText  \
# 104  Eau de Parfum  49.99         US $49.99        5.0  5 available / 45 sold
# 210              Y  49.99      US $49.99/ea        8.0  8 available / 68 sold
# 223  Eau de Parfum  46.99         US $46.99        2.0   2 available / 3 sold
# 448  Eau de Parfum  39.99      US $39.99/ea        8.0  8 available / 10 sold
#
#      sold                lastUpdated                       itemLocation
# 104  45.0  May 24, 2024 00:15:22 PDT          Ottawa,California, Canada
# 210  68.0  May 19, 2024 18:38:36 PDT          New Jersey, United States
# ...

# %%
mens_perfume[ mens_perfume['title'] == 'YSL Yves Saint Laurent Y Eau de Perfume Spray Cologne For Men 3.3 oz 100ML'].count()
# Out:
# brand                4
# title                4
# type                 4
# price                4
# priceWithCurrency    4
# available            4
# availableText        4
# sold                 4
# lastUpdated          4
# itemLocation         4
# dtype: int64

# %%
top_brand = mens_perfume.groupby('brand')['sold'].sum().sort_values(ascending=False)[:10]

# %%
top_brand
# Out:
# brand
# Calvin Klein     97572.0
# Versace          96519.0
# Davidoff         54944.0
# Azzaro           38305.0
# Armaf            24282.0
# Kenneth Cole     23716.0
# Paco Rabanne     21579.0
# Liz Claiborne    21341.0
# Burberry         19286.0
# 2nd To None      18882.0
# Name: sold, dtype: float64

# %%
mens_perfume.groupby(['brand', 'title'])['available'].sum().sort_values()[:15]
# Out:
# brand             title
# Penhaligon's      Penhaligon's The Tragedy of Lord George 2.5oz EDP Spray Men's Perfume               0.0
# Parfums de Marly  Parfums de Marly Kalan 4.2 fl oz / 125 ml Spray with box Men's Fragrances           0.0
# Paco Rabanne      Phantom by Paco Rabanne 5.1 oz EDT Refillable Cologne for Men Brand New In Box      0.0
#                   Paco Rabanne PHANTOM 100ml / 3.4 oz EDP INTENSE Sealed Authentic Fast Finescents    0.0
# Unbranded         Parfums De-Marly-Haltane Eau de Parfum spray 4.2 oz for Men New in Box              0.0
# Paco Rabanne      Paco Rabanne Invictus Legend 5.1 FL OZ / 150 ML EAU DE PARFUM SPRAY - RARE ITEM     0.0
# Claude Marsal     Lá Melodie Parfum                                                                   0.0
# Paco Rabanne      1 Million by Paco Rabanne 3.4 oz EDT Cologne for Men New Tester                     0.0
# Cologne           New 10x New Random Unique Men's Fragrance Cologne Sample Set Christimas Gift Set    0.0
# ...

# %%
mens_perfume.groupby(['brand'])['available'].sum().sort_values(ascending=False)
# Out:
# brand
# Ralph Lauren         1459.0
# Calvin Klein          994.0
# Guy Laroche           966.0
# Polo Ralph Lauren     824.0
# Liz Claiborne         648.0
#                       ...
# Fragrance Couture       0.0
# Reyane Tradition        0.0
# King                    0.0
# Jil Sander              0.0
# AS PICTURE SHOWN        0.0
# Name: available, Length: 246, dtype: float64

# %%
mens_perfume.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              999 non-null    object
#  1   title              1000 non-null   object
#  2   type               997 non-null    object
#  3   price              1000 non-null   float64
#  4   priceWithCurrency  1000 non-null   object
#  5   available          889 non-null    float64
#  6   availableText      997 non-null    object
#  7   sold               994 non-null    float64
#  8   lastUpdated        947 non-null    object
#  9   itemLocation       1000 non-null   object
# dtypes: float64(3), object(7)
# memory usage: 78.3+ KB

# %%
mens_perfume.isna()
# Out:
#      brand  title   type  price  priceWithCurrency  available  availableText  \
# 0    False  False  False  False              False      False          False
# 1    False  False  False  False              False      False          False
# 2    False  False  False  False              False      False          False
# 3    False  False  False  False              False      False          False
# 4    False  False  False  False              False       True          False
# ..     ...    ...    ...    ...                ...        ...            ...
# 995  False  False  False  False              False      False          False
# 996  False  False  False  False              False      False          False
# 997  False  False  False  False              False      False          False
# 998  False  False  False  False              False      False          False
# 999  False  False  False  False              False      False          False
#
#       sold  lastUpdated  itemLocation
# ...

# %%
mens_perfume[mens_perfume['available'].isna()]
# Out:
#                  brand                                              title  \
# 4              Lattafa  Lattafa Men's Hayaati Al Maleky EDP Spray 3.4 ...
# 7            Unbranded  Parfums De-Marly-Haltane Eau de Parfum spray 4...
# 20     Dolce & Gabbana  Light Blue by Dolce & Gabbana 4.2 oz Cologne f...
# 29        Penhaligon's  Penhaligon's The Tragedy of Lord George 2.5oz ...
# 36              Rasasi  Rasasi Men's Hawas EDP Spray 3.4 oz Fragrances...
# ..                 ...                                                ...
# 920   Elizabeth Taylor  Elizabeth Taylor PASSION Cologne Spray for Men...
# 922              Gucci  Gucci Guilty Black 3.0 oz EDT Cologne for Men ...
# 925  Bath & Body Works  Bath & Body Works Men's Collection Fragrance C...
# 934            Cologne  New 10x New Random Unique Men's Fragrance Colo...
# 988     Michael Jordan  Michael Jordan by Michael Jordan 3.4 oz Cologn...
#
#                 type  price priceWithCurrency  available  \
# ...

# %%
mens_perfume[mens_perfume['type'].isna()]
# Out:
#                   brand                                              title  \
# 81         Calvin Klein  Ck One by Calvin Klein Cologne Perfume Unisex ...
# 138             AS SHOW  Bleu De Eau de parfum EDP 100ml 3.4 oz Cologne...
# 606  Milestone Perfumes   Intimation By Milestone Eau de Parfum 3.4 oz Men
#
#     type  price priceWithCurrency  available  \
# 81   NaN  23.89      US $23.89/ea        NaN
# 138  NaN  89.99         US $89.99        5.0
# 606  NaN  19.89         US $19.89       10.0
#
#                                 availableText     sold  \
# 81   Limited quantity available / 54,052 sold  54052.0
# 138                      5 available / 5 sold      5.0
# 606          More than 10 available / 21 sold     21.0
#
#                    lastUpdated                           itemLocation
# 81   May 24, 2024 03:59:39 PDT  Hackensack, New Jersey, United States
# 138  May 14, 2024 20:43:05 PDT      New York,United States, Hong Kong
# ...

# %%
mens_perfume[mens_perfume.isnull().any(axis=1)]
# Out:
#                 brand                                              title  \
# 4             Lattafa  Lattafa Men's Hayaati Al Maleky EDP Spray 3.4 ...
# 7           Unbranded  Parfums De-Marly-Haltane Eau de Parfum spray 4...
# 20    Dolce & Gabbana  Light Blue by Dolce & Gabbana 4.2 oz Cologne f...
# 27             Azzaro  Azzaro The Most Wanted 3.38 oz./100 ml. PARFUM...
# 29       Penhaligon's  Penhaligon's The Tragedy of Lord George 2.5oz ...
# ..                ...                                                ...
# 934           Cologne  New 10x New Random Unique Men's Fragrance Colo...
# 945    Giorgio Armani  Lot of 12 - Acqua Di Gio Profondo - Men's Luxu...
# 948  Parfums de Marly  PDM PARFUMS DE MARLY LAYTON EXCLUSIF 1.5ml .05...
# 988    Michael Jordan  Michael Jordan by Michael Jordan 3.4 oz Cologn...
# 994     Dolce&Gabbana  Dolce & Gabbana Cologne For Men Eau De Toilett...
#
#                 type  price priceWithCurrency  available  \
# ...

# %%
mens_perfume[mens_perfume.isna().any(axis=1)]
# Out:
#                 brand                                              title  \
# 4             Lattafa  Lattafa Men's Hayaati Al Maleky EDP Spray 3.4 ...
# 7           Unbranded  Parfums De-Marly-Haltane Eau de Parfum spray 4...
# 20    Dolce & Gabbana  Light Blue by Dolce & Gabbana 4.2 oz Cologne f...
# 27             Azzaro  Azzaro The Most Wanted 3.38 oz./100 ml. PARFUM...
# 29       Penhaligon's  Penhaligon's The Tragedy of Lord George 2.5oz ...
# ..                ...                                                ...
# 934           Cologne  New 10x New Random Unique Men's Fragrance Colo...
# 945    Giorgio Armani  Lot of 12 - Acqua Di Gio Profondo - Men's Luxu...
# 948  Parfums de Marly  PDM PARFUMS DE MARLY LAYTON EXCLUSIF 1.5ml .05...
# 988    Michael Jordan  Michael Jordan by Michael Jordan 3.4 oz Cologn...
# 994     Dolce&Gabbana  Dolce & Gabbana Cologne For Men Eau De Toilett...
#
#                 type  price priceWithCurrency  available  \
# ...

# %%
perfume = mens_perfume.copy()

# %%
perfume.dropna(axis=0, inplace=True)

# %%
perfume.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 842 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              842 non-null    object
#  1   title              842 non-null    object
#  2   type               842 non-null    object
#  3   price              842 non-null    float64
#  4   priceWithCurrency  842 non-null    object
#  5   available          842 non-null    float64
#  6   availableText      842 non-null    object
#  7   sold               842 non-null    float64
#  8   lastUpdated        842 non-null    object
#  9   itemLocation       842 non-null    object
# dtypes: float64(3), object(7)
# memory usage: 72.4+ KB

# %%
mens_perfume.dropna(axis=1)
# Out:
#                                                  title   price  \
# 0    Christian Dior Sauvage Men's EDP 3.4 oz Fragra...   84.99
# 1    A-v-entus Eau de Parfum 3.3 oz 100ML Millesime...  109.99
# 2                     HOGO BOSS cologne For Men 3.4 oz  100.00
# 3    Acqua Di Gio by Giorgio Armani 6.7 Fl oz Eau D...   44.99
# 4    Lattafa Men's Hayaati Al Maleky EDP Spray 3.4 ...   16.91
# ..                                                 ...     ...
# 995  Guess 1981 by Guess cologne for men EDT 3.3 / ...   20.28
# 996  Club de Nuit Intense by Armaf cologne for men ...   30.58
# 997  Invictus by Paco Rabanne for Men EDT Spray 3.4...   39.99
# 998  Lomani EDT Cologne 3.4 oz Men - Authentic, Bra...    9.99
# 999  Beyond Paradise by Estee Lauder for Men Cologn...   17.49
#
#     priceWithCurrency                            itemLocation
# 0        US $84.99/ea     Allen Park, Michigan, United States
# 1          US $109.99                Atlanta, Georgia, Canada
# ...

# %%
fill = mens_perfume.copy()

# %%
fill.fillna('will be updated')
# Out:
#               brand                                              title  \
# 0              Dior  Christian Dior Sauvage Men's EDP 3.4 oz Fragra...
# 1           AS SHOW  A-v-entus Eau de Parfum 3.3 oz 100ML Millesime...
# 2         Unbranded                   HOGO BOSS cologne For Men 3.4 oz
# 3    Giorgio Armani  Acqua Di Gio by Giorgio Armani 6.7 Fl oz Eau D...
# 4           Lattafa  Lattafa Men's Hayaati Al Maleky EDP Spray 3.4 ...
# ..              ...                                                ...
# 995           GUESS  Guess 1981 by Guess cologne for men EDT 3.3 / ...
# 996           Armaf  Club de Nuit Intense by Armaf cologne for men ...
# 997    Paco Rabanne  Invictus by Paco Rabanne for Men EDT Spray 3.4...
# 998          Lomani  Lomani EDT Cologne 3.4 oz Men - Authentic, Bra...
# 999    Estee Lauder  Beyond Paradise by Estee Lauder for Men Cologn...
#
#                 type   price priceWithCurrency        available  \
# ...

# %%
fill['available'].fillna(0)
# Out:
# 0      10.0
# 1       8.0
# 2      10.0
# 3       2.0
# 4       0.0
#        ...
# 995    45.0
# 996    10.0
# 997     2.0
# 998     2.0
# 999    10.0
# Name: available, Length: 1000, dtype: float64

# %%
fill['available'].fillna(fill['available'].mean())
# Out:
# 0      10.000000
# 1       8.000000
# 2      10.000000
# 3       2.000000
# 4      20.046119
#          ...
# 995    45.000000
# 996    10.000000
# 997     2.000000
# 998     2.000000
# 999    10.000000
# Name: available, Length: 1000, dtype: float64

# %%
fill['available'].fillna(fill['available'].sum())
# Out:
# 0         10.0
# 1          8.0
# 2         10.0
# 3          2.0
# 4      17821.0
#         ...
# 995       45.0
# 996       10.0
# 997        2.0
# 998        2.0
# 999       10.0
# Name: available, Length: 1000, dtype: float64

# %%
fill['available'].fillna(fill['available'].std())
# Out:
# 0      10.000000
# 1       8.000000
# 2      10.000000
# 3       2.000000
# 4      61.547985
#          ...
# 995    45.000000
# 996    10.000000
# 997     2.000000
# 998     2.000000
# 999    10.000000
# Name: available, Length: 1000, dtype: float64

# %%
fill['available'].ffill()
# Out:
# 0      10.0
# 1       8.0
# 2      10.0
# 3       2.0
# 4       2.0
#        ...
# 995    45.0
# 996    10.0
# 997     2.0
# 998     2.0
# 999    10.0
# Name: available, Length: 1000, dtype: float64

# %%
fill['available'].bfill()
# Out:
# 0      10.0
# 1       8.0
# 2      10.0
# 3       2.0
# 4      10.0
#        ...
# 995    45.0
# 996    10.0
# 997     2.0
# 998     2.0
# 999    10.0
# Name: available, Length: 1000, dtype: float64

# %%
fill.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              999 non-null    object
#  1   title              1000 non-null   object
#  2   type               997 non-null    object
#  3   price              1000 non-null   float64
#  4   priceWithCurrency  1000 non-null   object
#  5   available          889 non-null    float64
#  6   availableText      997 non-null    object
#  7   sold               994 non-null    float64
#  8   lastUpdated        947 non-null    object
#  9   itemLocation       1000 non-null   object
# dtypes: float64(3), object(7)
# memory usage: 78.3+ KB

# %%
fill['available'].ffill(inplace=True)

# %%
fill
# Out:
#               brand                                              title  \
# 0              Dior  Christian Dior Sauvage Men's EDP 3.4 oz Fragra...
# 1           AS SHOW  A-v-entus Eau de Parfum 3.3 oz 100ML Millesime...
# 2         Unbranded                   HOGO BOSS cologne For Men 3.4 oz
# 3    Giorgio Armani  Acqua Di Gio by Giorgio Armani 6.7 Fl oz Eau D...
# 4           Lattafa  Lattafa Men's Hayaati Al Maleky EDP Spray 3.4 ...
# ..              ...                                                ...
# 995           GUESS  Guess 1981 by Guess cologne for men EDT 3.3 / ...
# 996           Armaf  Club de Nuit Intense by Armaf cologne for men ...
# 997    Paco Rabanne  Invictus by Paco Rabanne for Men EDT Spray 3.4...
# 998          Lomani  Lomani EDT Cologne 3.4 oz Men - Authentic, Bra...
# 999    Estee Lauder  Beyond Paradise by Estee Lauder for Men Cologn...
#
#                 type   price priceWithCurrency  available  \
# ...

# %%
fill['type'].fillna('not specified', inplace=True)

# %%
fill
# Out:
#               brand                                              title  \
# 0              Dior  Christian Dior Sauvage Men's EDP 3.4 oz Fragra...
# 1           AS SHOW  A-v-entus Eau de Parfum 3.3 oz 100ML Millesime...
# 2         Unbranded                   HOGO BOSS cologne For Men 3.4 oz
# 3    Giorgio Armani  Acqua Di Gio by Giorgio Armani 6.7 Fl oz Eau D...
# 4           Lattafa  Lattafa Men's Hayaati Al Maleky EDP Spray 3.4 ...
# ..              ...                                                ...
# 995           GUESS  Guess 1981 by Guess cologne for men EDT 3.3 / ...
# 996           Armaf  Club de Nuit Intense by Armaf cologne for men ...
# 997    Paco Rabanne  Invictus by Paco Rabanne for Men EDT Spray 3.4...
# 998          Lomani  Lomani EDT Cologne 3.4 oz Men - Authentic, Bra...
# 999    Estee Lauder  Beyond Paradise by Estee Lauder for Men Cologn...
#
#                 type   price priceWithCurrency  available  \
# ...

# %%
fill['brand'].fillna('unbranded', inplace=True)

# %%
fill
# Out:
#               brand                                              title  \
# 0              Dior  Christian Dior Sauvage Men's EDP 3.4 oz Fragra...
# 1           AS SHOW  A-v-entus Eau de Parfum 3.3 oz 100ML Millesime...
# 2         Unbranded                   HOGO BOSS cologne For Men 3.4 oz
# 3    Giorgio Armani  Acqua Di Gio by Giorgio Armani 6.7 Fl oz Eau D...
# 4           Lattafa  Lattafa Men's Hayaati Al Maleky EDP Spray 3.4 ...
# ..              ...                                                ...
# 995           GUESS  Guess 1981 by Guess cologne for men EDT 3.3 / ...
# 996           Armaf  Club de Nuit Intense by Armaf cologne for men ...
# 997    Paco Rabanne  Invictus by Paco Rabanne for Men EDT Spray 3.4...
# 998          Lomani  Lomani EDT Cologne 3.4 oz Men - Authentic, Bra...
# 999    Estee Lauder  Beyond Paradise by Estee Lauder for Men Cologn...
#
#                 type   price priceWithCurrency  available  \
# ...

# %%
fill['lastUpdated'].bfill(inplace=True)

# %%
fill
# Out:
#               brand                                              title  \
# 0              Dior  Christian Dior Sauvage Men's EDP 3.4 oz Fragra...
# 1           AS SHOW  A-v-entus Eau de Parfum 3.3 oz 100ML Millesime...
# 2         Unbranded                   HOGO BOSS cologne For Men 3.4 oz
# 3    Giorgio Armani  Acqua Di Gio by Giorgio Armani 6.7 Fl oz Eau D...
# 4           Lattafa  Lattafa Men's Hayaati Al Maleky EDP Spray 3.4 ...
# ..              ...                                                ...
# 995           GUESS  Guess 1981 by Guess cologne for men EDT 3.3 / ...
# 996           Armaf  Club de Nuit Intense by Armaf cologne for men ...
# 997    Paco Rabanne  Invictus by Paco Rabanne for Men EDT Spray 3.4...
# 998          Lomani  Lomani EDT Cologne 3.4 oz Men - Authentic, Bra...
# 999    Estee Lauder  Beyond Paradise by Estee Lauder for Men Cologn...
#
#                 type   price priceWithCurrency  available  \
# ...

# %%
fill['sold'].fillna('missing', inplace=True)

# %%
fill
# Out:
#               brand                                              title  \
# 0              Dior  Christian Dior Sauvage Men's EDP 3.4 oz Fragra...
# 1           AS SHOW  A-v-entus Eau de Parfum 3.3 oz 100ML Millesime...
# 2         Unbranded                   HOGO BOSS cologne For Men 3.4 oz
# 3    Giorgio Armani  Acqua Di Gio by Giorgio Armani 6.7 Fl oz Eau D...
# 4           Lattafa  Lattafa Men's Hayaati Al Maleky EDP Spray 3.4 ...
# ..              ...                                                ...
# 995           GUESS  Guess 1981 by Guess cologne for men EDT 3.3 / ...
# 996           Armaf  Club de Nuit Intense by Armaf cologne for men ...
# 997    Paco Rabanne  Invictus by Paco Rabanne for Men EDT Spray 3.4...
# 998          Lomani  Lomani EDT Cologne 3.4 oz Men - Authentic, Bra...
# 999    Estee Lauder  Beyond Paradise by Estee Lauder for Men Cologn...
#
#                 type   price priceWithCurrency  available  \
# ...

# %%
fill['availableText'].fillna('not generated', inplace=True)

# %%
fill
# Out:
#               brand                                              title  \
# 0              Dior  Christian Dior Sauvage Men's EDP 3.4 oz Fragra...
# 1           AS SHOW  A-v-entus Eau de Parfum 3.3 oz 100ML Millesime...
# 2         Unbranded                   HOGO BOSS cologne For Men 3.4 oz
# 3    Giorgio Armani  Acqua Di Gio by Giorgio Armani 6.7 Fl oz Eau D...
# 4           Lattafa  Lattafa Men's Hayaati Al Maleky EDP Spray 3.4 ...
# ..              ...                                                ...
# 995           GUESS  Guess 1981 by Guess cologne for men EDT 3.3 / ...
# 996           Armaf  Club de Nuit Intense by Armaf cologne for men ...
# 997    Paco Rabanne  Invictus by Paco Rabanne for Men EDT Spray 3.4...
# 998          Lomani  Lomani EDT Cologne 3.4 oz Men - Authentic, Bra...
# 999    Estee Lauder  Beyond Paradise by Estee Lauder for Men Cologn...
#
#                 type   price priceWithCurrency  available  \
# ...

# %%
fill.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              1000 non-null   object
#  1   title              1000 non-null   object
#  2   type               1000 non-null   object
#  3   price              1000 non-null   float64
#  4   priceWithCurrency  1000 non-null   object
#  5   available          1000 non-null   float64
#  6   availableText      1000 non-null   object
#  7   sold               1000 non-null   object
#  8   lastUpdated        1000 non-null   object
#  9   itemLocation       1000 non-null   object
# dtypes: float64(2), object(8)
# memory usage: 78.3+ KB
