# %%
import pandas as pd

# %%
women_perfume = pd.read_csv('./ebay_womens_perfume.csv')

# %%
women_perfume
# Out:
#                   brand                                              title  \
# 0      Carolina Herrera  Good Girl by Carolina Herrera 2.7 oz Eau De Pa...
# 1              As Shown  Parfums de Marly Delina La Rosee Eau de Parfum...
# 2                 PRADA  PRADA Paradoxe by Prada EDP 3.0oz/90ml Spray P...
# 3               As Show  J'adore Parfum D'eau by Christian 3.4 oz EDP F...
# 4               Khadlaj  Shiyaaka for Men EDP Spray 100ML (3.4 FL.OZ) B...
# ..                  ...                                                ...
# 995                Avon  Avon Far Away Infinity Eau de Parfum 1.7 fl. o...
# 996             Mancera  Roses Greedy by Mancera perfume for unisex EDP...
# 997           Unbranded  Sweet Tooth Eau de Parfum, Perfume for Women, ...
# 998  Juliette Has A Gun  MMMM BY Juliette Has A Gun perfume for her EDP...
# 999        Paris Hilton  PARIS HILTON ELECTRIFY for Women Cologne 3.4 o...
#
#                type  price priceWithCurrency  available  \
# ...

# %%
women_perfume.dropna()
# Out:
#                   brand                                              title  \
# 0      Carolina Herrera  Good Girl by Carolina Herrera 2.7 oz Eau De Pa...
# 1              As Shown  Parfums de Marly Delina La Rosee Eau de Parfum...
# 2                 PRADA  PRADA Paradoxe by Prada EDP 3.0oz/90ml Spray P...
# 3               As Show  J'adore Parfum D'eau by Christian 3.4 oz EDP F...
# 5         Viktor & Rolf  Flowerbomb by Viktor & Rolf 3.4 oz 100ML Eau D...
# ..                  ...                                                ...
# 995                Avon  Avon Far Away Infinity Eau de Parfum 1.7 fl. o...
# 996             Mancera  Roses Greedy by Mancera perfume for unisex EDP...
# 997           Unbranded  Sweet Tooth Eau de Parfum, Perfume for Women, ...
# 998  Juliette Has A Gun  MMMM BY Juliette Has A Gun perfume for her EDP...
# 999        Paris Hilton  PARIS HILTON ELECTRIFY for Women Cologne 3.4 o...
#
#                type  price priceWithCurrency  available  \
# ...

# %%
women_perfume.dropna(how='all')
# Out:
#                   brand                                              title  \
# 0      Carolina Herrera  Good Girl by Carolina Herrera 2.7 oz Eau De Pa...
# 1              As Shown  Parfums de Marly Delina La Rosee Eau de Parfum...
# 2                 PRADA  PRADA Paradoxe by Prada EDP 3.0oz/90ml Spray P...
# 3               As Show  J'adore Parfum D'eau by Christian 3.4 oz EDP F...
# 4               Khadlaj  Shiyaaka for Men EDP Spray 100ML (3.4 FL.OZ) B...
# ..                  ...                                                ...
# 995                Avon  Avon Far Away Infinity Eau de Parfum 1.7 fl. o...
# 996             Mancera  Roses Greedy by Mancera perfume for unisex EDP...
# 997           Unbranded  Sweet Tooth Eau de Parfum, Perfume for Women, ...
# 998  Juliette Has A Gun  MMMM BY Juliette Has A Gun perfume for her EDP...
# 999        Paris Hilton  PARIS HILTON ELECTRIFY for Women Cologne 3.4 o...
#
#                type  price priceWithCurrency  available  \
# ...

# %%
women_perfume.dropna(how='any')
# Out:
#                   brand                                              title  \
# 0      Carolina Herrera  Good Girl by Carolina Herrera 2.7 oz Eau De Pa...
# 1              As Shown  Parfums de Marly Delina La Rosee Eau de Parfum...
# 2                 PRADA  PRADA Paradoxe by Prada EDP 3.0oz/90ml Spray P...
# 3               As Show  J'adore Parfum D'eau by Christian 3.4 oz EDP F...
# 5         Viktor & Rolf  Flowerbomb by Viktor & Rolf 3.4 oz 100ML Eau D...
# ..                  ...                                                ...
# 995                Avon  Avon Far Away Infinity Eau de Parfum 1.7 fl. o...
# 996             Mancera  Roses Greedy by Mancera perfume for unisex EDP...
# 997           Unbranded  Sweet Tooth Eau de Parfum, Perfume for Women, ...
# 998  Juliette Has A Gun  MMMM BY Juliette Has A Gun perfume for her EDP...
# 999        Paris Hilton  PARIS HILTON ELECTRIFY for Women Cologne 3.4 o...
#
#                type  price priceWithCurrency  available  \
# ...

# %%
women_perfume.dropna(thresh=8)
# Out:
#                   brand                                              title  \
# 0      Carolina Herrera  Good Girl by Carolina Herrera 2.7 oz Eau De Pa...
# 1              As Shown  Parfums de Marly Delina La Rosee Eau de Parfum...
# 2                 PRADA  PRADA Paradoxe by Prada EDP 3.0oz/90ml Spray P...
# 3               As Show  J'adore Parfum D'eau by Christian 3.4 oz EDP F...
# 4               Khadlaj  Shiyaaka for Men EDP Spray 100ML (3.4 FL.OZ) B...
# ..                  ...                                                ...
# 995                Avon  Avon Far Away Infinity Eau de Parfum 1.7 fl. o...
# 996             Mancera  Roses Greedy by Mancera perfume for unisex EDP...
# 997           Unbranded  Sweet Tooth Eau de Parfum, Perfume for Women, ...
# 998  Juliette Has A Gun  MMMM BY Juliette Has A Gun perfume for her EDP...
# 999        Paris Hilton  PARIS HILTON ELECTRIFY for Women Cologne 3.4 o...
#
#                type  price priceWithCurrency  available  \
# ...

# %%
women_perfume.fillna(0)
# Out:
#                   brand                                              title  \
# 0      Carolina Herrera  Good Girl by Carolina Herrera 2.7 oz Eau De Pa...
# 1              As Shown  Parfums de Marly Delina La Rosee Eau de Parfum...
# 2                 PRADA  PRADA Paradoxe by Prada EDP 3.0oz/90ml Spray P...
# 3               As Show  J'adore Parfum D'eau by Christian 3.4 oz EDP F...
# 4               Khadlaj  Shiyaaka for Men EDP Spray 100ML (3.4 FL.OZ) B...
# ..                  ...                                                ...
# 995                Avon  Avon Far Away Infinity Eau de Parfum 1.7 fl. o...
# 996             Mancera  Roses Greedy by Mancera perfume for unisex EDP...
# 997           Unbranded  Sweet Tooth Eau de Parfum, Perfume for Women, ...
# 998  Juliette Has A Gun  MMMM BY Juliette Has A Gun perfume for her EDP...
# 999        Paris Hilton  PARIS HILTON ELECTRIFY for Women Cologne 3.4 o...
#
#                type  price priceWithCurrency  available  \
# ...

# %%
women_perfume.fillna('empty data')
# Out:
#                   brand                                              title  \
# 0      Carolina Herrera  Good Girl by Carolina Herrera 2.7 oz Eau De Pa...
# 1              As Shown  Parfums de Marly Delina La Rosee Eau de Parfum...
# 2                 PRADA  PRADA Paradoxe by Prada EDP 3.0oz/90ml Spray P...
# 3               As Show  J'adore Parfum D'eau by Christian 3.4 oz EDP F...
# 4               Khadlaj  Shiyaaka for Men EDP Spray 100ML (3.4 FL.OZ) B...
# ..                  ...                                                ...
# 995                Avon  Avon Far Away Infinity Eau de Parfum 1.7 fl. o...
# 996             Mancera  Roses Greedy by Mancera perfume for unisex EDP...
# 997           Unbranded  Sweet Tooth Eau de Parfum, Perfume for Women, ...
# 998  Juliette Has A Gun  MMMM BY Juliette Has A Gun perfume for her EDP...
# 999        Paris Hilton  PARIS HILTON ELECTRIFY for Women Cologne 3.4 o...
#
#                type  price priceWithCurrency available  \
# ...

# %%
women_perfume.fillna(method='ffill')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13644\122087772.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   women_perfume.fillna(method='ffill')
#                   brand                                              title  \
# 0      Carolina Herrera  Good Girl by Carolina Herrera 2.7 oz Eau De Pa...
# 1              As Shown  Parfums de Marly Delina La Rosee Eau de Parfum...
# 2                 PRADA  PRADA Paradoxe by Prada EDP 3.0oz/90ml Spray P...
# 3               As Show  J'adore Parfum D'eau by Christian 3.4 oz EDP F...
# 4               Khadlaj  Shiyaaka for Men EDP Spray 100ML (3.4 FL.OZ) B...
# ..                  ...                                                ...
# 995                Avon  Avon Far Away Infinity Eau de Parfum 1.7 fl. o...
# 996             Mancera  Roses Greedy by Mancera perfume for unisex EDP...
# ...

# %%
women_perfume.fillna(method='bfill')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13644\159911712.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   women_perfume.fillna(method='bfill')
#                   brand                                              title  \
# 0      Carolina Herrera  Good Girl by Carolina Herrera 2.7 oz Eau De Pa...
# 1              As Shown  Parfums de Marly Delina La Rosee Eau de Parfum...
# 2                 PRADA  PRADA Paradoxe by Prada EDP 3.0oz/90ml Spray P...
# 3               As Show  J'adore Parfum D'eau by Christian 3.4 oz EDP F...
# 4               Khadlaj  Shiyaaka for Men EDP Spray 100ML (3.4 FL.OZ) B...
# ..                  ...                                                ...
# 995                Avon  Avon Far Away Infinity Eau de Parfum 1.7 fl. o...
# 996             Mancera  Roses Greedy by Mancera perfume for unisex EDP...
# ...

# %%
women_perfume['sold'].fillna(women_perfume['sold'].min())
# Out:
# 0      393.0
# 1       40.0
# 2       35.0
# 3        9.0
# 4        1.0
#        ...
# 995    157.0
# 996     58.0
# 997      3.0
# 998    117.0
# 999     51.0
# Name: sold, Length: 1000, dtype: float64

# %%
women_perfume.duplicated().value_counts()
# Out:
# False    999
# True       1
# Name: count, dtype: int64

# %%
women_perfume.duplicated(subset=['title', 'type']).value_counts()
# Out:
# False    975
# True      25
# Name: count, dtype: int64

# %%
women_perfume.duplicated(subset=['title', 'type'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
women_perfume.duplicated(subset=['title', 'type'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
women_perfume[women_perfume.duplicated()]
# Out:
#       brand                                              title     type  \
# 662  FLOWER  12 Piece Woman’s Perfume Lot: Assorted scents ...  Perfume
#
#      price priceWithCurrency  available         availableText  sold  \
# 662   48.0         US $48.00        4.0  4 available / 1 sold   1.0
#
#     lastUpdated                     itemLocation
# 662         NaN  Webster, Florida, United States

# %%
women_perfume[women_perfume['brand'] == 'FLOWER']
# Out:
#       brand                                              title     type  \
# 344  FLOWER  12 Piece Woman’s Perfume Lot: Assorted scents ...  Perfume
# 662  FLOWER  12 Piece Woman’s Perfume Lot: Assorted scents ...  Perfume
#
#      price priceWithCurrency  available         availableText  sold  \
# 344   48.0         US $48.00        4.0  4 available / 1 sold   1.0
# 662   48.0         US $48.00        4.0  4 available / 1 sold   1.0
#
#     lastUpdated                     itemLocation
# 344         NaN  Webster, Florida, United States
# 662         NaN  Webster, Florida, United States

# %%
women_perfume.drop_duplicates()
# Out:
#                   brand                                              title  \
# 0      Carolina Herrera  Good Girl by Carolina Herrera 2.7 oz Eau De Pa...
# 1              As Shown  Parfums de Marly Delina La Rosee Eau de Parfum...
# 2                 PRADA  PRADA Paradoxe by Prada EDP 3.0oz/90ml Spray P...
# 3               As Show  J'adore Parfum D'eau by Christian 3.4 oz EDP F...
# 4               Khadlaj  Shiyaaka for Men EDP Spray 100ML (3.4 FL.OZ) B...
# ..                  ...                                                ...
# 995                Avon  Avon Far Away Infinity Eau de Parfum 1.7 fl. o...
# 996             Mancera  Roses Greedy by Mancera perfume for unisex EDP...
# 997           Unbranded  Sweet Tooth Eau de Parfum, Perfume for Women, ...
# 998  Juliette Has A Gun  MMMM BY Juliette Has A Gun perfume for her EDP...
# 999        Paris Hilton  PARIS HILTON ELECTRIFY for Women Cologne 3.4 o...
#
#                type  price priceWithCurrency  available  \
# ...

# %%
women_perfume.drop_duplicates(subset=['title', 'type'])
# Out:
#                   brand                                              title  \
# 0      Carolina Herrera  Good Girl by Carolina Herrera 2.7 oz Eau De Pa...
# 1              As Shown  Parfums de Marly Delina La Rosee Eau de Parfum...
# 2                 PRADA  PRADA Paradoxe by Prada EDP 3.0oz/90ml Spray P...
# 3               As Show  J'adore Parfum D'eau by Christian 3.4 oz EDP F...
# 4               Khadlaj  Shiyaaka for Men EDP Spray 100ML (3.4 FL.OZ) B...
# ..                  ...                                                ...
# 995                Avon  Avon Far Away Infinity Eau de Parfum 1.7 fl. o...
# 996             Mancera  Roses Greedy by Mancera perfume for unisex EDP...
# 997           Unbranded  Sweet Tooth Eau de Parfum, Perfume for Women, ...
# 998  Juliette Has A Gun  MMMM BY Juliette Has A Gun perfume for her EDP...
# 999        Paris Hilton  PARIS HILTON ELECTRIFY for Women Cologne 3.4 o...
#
#                type  price priceWithCurrency  available  \
# ...

# %%
dropped = women_perfume.drop_duplicates()
dropped.iloc[660 : 665]
# Out:
#               brand                                              title  \
# 660             JLO  Glow by J.LO Jennifer Lopez Perfume for Women ...
# 661  Gianni Versace  Versace VERSENSE EDT for Women 3.3 / 3.4 oz Ne...
# 663  Ainash Perfums  Royal Noir Absolu by Ainash 2.5 oz Extrait de ...
# 664  Britney Spears  Curious By Britney Spears Mini EDP Splash Perf...
# 665         Lancôme  La Vie Est Belle by Lancome 3.4 oz / 100 ml Sp...
#
#                   type  price priceWithCurrency  available  \
# 660    Eau de Toilette  26.81      US $26.81/ea        NaN
# 661    Eau de Toilette  38.76      US $38.76/ea        NaN
# 663  Extrait de Parfum  58.50         US $58.50       10.0
# 664      Eau de Parfum  10.99      US $10.99/ea        8.0
# 665      Eau de Parfum  42.99      US $42.99/ea        2.0
#
#                              availableText   sold                lastUpdated  \
# 660  Limited quantity available / 478 sold  478.0  May 24, 2024 09:37:10 PDT
# ...

# %%
women_perfume.columns.to_list()
# Out:
# ['brand',
#  'title',
#  'type',
#  'price',
#  'priceWithCurrency',
#  'available',
#  'availableText',
#  'sold',
#  'lastUpdated',
#  'itemLocation']

# %%
women_perfume.columns = ['brand', 'title', 'type', 'price', 'priceInCurrency', 'available', 'availableInText', 'sold','lastUpdated', 'Location']

# %%
women_perfume
# Out:
#                   brand                                              title  \
# 0      Carolina Herrera  Good Girl by Carolina Herrera 2.7 oz Eau De Pa...
# 1              As Shown  Parfums de Marly Delina La Rosee Eau de Parfum...
# 2                 PRADA  PRADA Paradoxe by Prada EDP 3.0oz/90ml Spray P...
# 3               As Show  J'adore Parfum D'eau by Christian 3.4 oz EDP F...
# 4               Khadlaj  Shiyaaka for Men EDP Spray 100ML (3.4 FL.OZ) B...
# ..                  ...                                                ...
# 995                Avon  Avon Far Away Infinity Eau de Parfum 1.7 fl. o...
# 996             Mancera  Roses Greedy by Mancera perfume for unisex EDP...
# 997           Unbranded  Sweet Tooth Eau de Parfum, Perfume for Women, ...
# 998  Juliette Has A Gun  MMMM BY Juliette Has A Gun perfume for her EDP...
# 999        Paris Hilton  PARIS HILTON ELECTRIFY for Women Cologne 3.4 o...
#
#                type  price priceInCurrency  available  \
# ...

# %%
women_perfume.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   brand            999 non-null    object
#  1   title            1000 non-null   object
#  2   type             998 non-null    object
#  3   price            1000 non-null   float64
#  4   priceInCurrency  1000 non-null   object
#  5   available        869 non-null    float64
#  6   availableInText  992 non-null    object
#  7   sold             984 non-null    float64
#  8   lastUpdated      927 non-null    object
#  9   Location         1000 non-null   object
# dtypes: float64(3), object(7)
# memory usage: 78.3+ KB

# %%
women_perfume['sold'].fillna(0, inplace=True)
women_perfume['sold'] = women_perfume['sold'].astype('int')

# %%
women_perfume
# Out:
#                   brand                                              title  \
# 0      Carolina Herrera  Good Girl by Carolina Herrera 2.7 oz Eau De Pa...
# 1              As Shown  Parfums de Marly Delina La Rosee Eau de Parfum...
# 2                 PRADA  PRADA Paradoxe by Prada EDP 3.0oz/90ml Spray P...
# 3               As Show  J'adore Parfum D'eau by Christian 3.4 oz EDP F...
# 4               Khadlaj  Shiyaaka for Men EDP Spray 100ML (3.4 FL.OZ) B...
# ..                  ...                                                ...
# 995                Avon  Avon Far Away Infinity Eau de Parfum 1.7 fl. o...
# 996             Mancera  Roses Greedy by Mancera perfume for unisex EDP...
# 997           Unbranded  Sweet Tooth Eau de Parfum, Perfume for Women, ...
# 998  Juliette Has A Gun  MMMM BY Juliette Has A Gun perfume for her EDP...
# 999        Paris Hilton  PARIS HILTON ELECTRIFY for Women Cologne 3.4 o...
#
#                type  price priceInCurrency  available  \
# ...

# %%
women_perfume['available'].fillna(0, inplace=True)
women_perfume['available'] = women_perfume['available'].astype('int')

# %%
women_perfume
# Out:
#                   brand                                              title  \
# 0      Carolina Herrera  Good Girl by Carolina Herrera 2.7 oz Eau De Pa...
# 1              As Shown  Parfums de Marly Delina La Rosee Eau de Parfum...
# 2                 PRADA  PRADA Paradoxe by Prada EDP 3.0oz/90ml Spray P...
# 3               As Show  J'adore Parfum D'eau by Christian 3.4 oz EDP F...
# 4               Khadlaj  Shiyaaka for Men EDP Spray 100ML (3.4 FL.OZ) B...
# ..                  ...                                                ...
# 995                Avon  Avon Far Away Infinity Eau de Parfum 1.7 fl. o...
# 996             Mancera  Roses Greedy by Mancera perfume for unisex EDP...
# 997           Unbranded  Sweet Tooth Eau de Parfum, Perfume for Women, ...
# 998  Juliette Has A Gun  MMMM BY Juliette Has A Gun perfume for her EDP...
# 999        Paris Hilton  PARIS HILTON ELECTRIFY for Women Cologne 3.4 o...
#
#                type  price priceInCurrency  available  \
# ...

# %%
women_perfume.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   brand            999 non-null    object
#  1   title            1000 non-null   object
#  2   type             998 non-null    object
#  3   price            1000 non-null   float64
#  4   priceInCurrency  1000 non-null   object
#  5   available        1000 non-null   int32
#  6   availableInText  992 non-null    object
#  7   sold             1000 non-null   int32
#  8   lastUpdated      927 non-null    object
#  9   Location         1000 non-null   object
# dtypes: float64(1), int32(2), object(7)
# memory usage: 70.4+ KB

# %%
women_perfume['lastUpdated'].ffill(inplace=True)

# %%
women_perfume['lastUpdated'] = pd.to_datetime(women_perfume['lastUpdated'], format='mixed')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13644\3648143090.py:1: FutureWarning: Parsed string "May 23, 2024 10:43:50 PDT" included an un-recognized timezone "PDT". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   women_perfume['lastUpdated'] = pd.to_datetime(women_perfume['lastUpdated'], format='mixed')
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13644\3648143090.py:1: FutureWarning: Parsed string "May 24, 2024 00:15:48 PDT" included an un-recognized timezone "PDT". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   women_perfume['lastUpdated'] = pd.to_datetime(women_perfume['lastUpdated'], format='mixed')
# ...

# %%
women_perfume.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   brand            999 non-null    object
#  1   title            1000 non-null   object
#  2   type             998 non-null    object
#  3   price            1000 non-null   float64
#  4   priceInCurrency  1000 non-null   object
#  5   available        1000 non-null   int32
#  6   availableInText  992 non-null    object
#  7   sold             1000 non-null   int32
#  8   lastUpdated      1000 non-null   datetime64[ns]
#  9   Location         1000 non-null   object
# dtypes: datetime64[ns](1), float64(1), int32(2), object(6)
# memory usage: 70.4+ KB

# %%
women_perfume['title'].str.strip()
# Out:
# 0      Good Girl by Carolina Herrera 2.7 oz Eau De Pa...
# 1      Parfums de Marly Delina La Rosee Eau de Parfum...
# 2      PRADA Paradoxe by Prada EDP 3.0oz/90ml Spray P...
# 3      J'adore Parfum D'eau by Christian 3.4 oz EDP F...
# 4      Shiyaaka for Men EDP Spray 100ML (3.4 FL.OZ) B...
#                              ...
# 995    Avon Far Away Infinity Eau de Parfum 1.7 fl. o...
# 996    Roses Greedy by Mancera perfume for unisex EDP...
# 997    Sweet Tooth Eau de Parfum, Perfume for Women, ...
# 998    MMMM BY Juliette Has A Gun perfume for her EDP...
# 999    PARIS HILTON ELECTRIFY for Women Cologne 3.4 o...
# Name: title, Length: 1000, dtype: object

# %%
cleaning_df = pd.read_excel('./Data Cleaning Excel Tutorial (1).xlsx')

# %%
cleaning_df
# Out:
#     Unnamed: 0  S.No.               president         President Fixed  \
# 0            0      1       George Washington       George Washington
# 1            1      2              john adams              John Adams
# 2            2      3        Thomas Jefferson        Thomas Jefferson
# 3            3      4           James Madison           James Madison
# 4            4      5            JAMES MONROE            James Monroe
# 5            5      6       John Quincy Adams       John Quincy Adams
# 6            6      7          Andrew Jackson          Andrew Jackson
# 7            7      8        Martin Van Buren        Martin Van Buren
# 8            8      9  William Henry Harrison  William Henry Harrison
# 9            9     10              john tyler              John Tyler
# 10          10     11           James K. Polk           James K. Polk
# 11          11     12          Zachary Taylor          Zachary Taylor
# ...

# %%
cleaning_df.columns
# Out:
# Index(['Unnamed: 0', 'S.No.', 'president', 'President Fixed', 'prior', 'party',
#        'vice', 'Vice Fixed', 'salary', 'date updated', 'date created'],
#       dtype='object')

# %%
# Removing a columu
cleaning_df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
cleaning_df
# Out:
#     S.No.               president         President Fixed  \
# 0       1       George Washington       George Washington
# 1       2              john adams              John Adams
# 2       3        Thomas Jefferson        Thomas Jefferson
# 3       4           James Madison           James Madison
# 4       5            JAMES MONROE            James Monroe
# 5       6       John Quincy Adams       John Quincy Adams
# 6       7          Andrew Jackson          Andrew Jackson
# 7       8        Martin Van Buren        Martin Van Buren
# 8       9  William Henry Harrison  William Henry Harrison
# 9      10              john tyler              John Tyler
# 10     11           James K. Polk           James K. Polk
# 11     12          Zachary Taylor          Zachary Taylor
# 12     13        Millard Fillmore        Millard Fillmore
# 13     14         Franklin Pierce         Franklin Pierce
# 14     15          James Buchanan          James Buchanan
# ...

# %%
cleaning_df['prior'].unique()
# Out:
# array(['Commander-in-Chief  of the  Continental Army   ( 1775 - 1783 )',
#        '1st  Vice President of the United States',
#        '2nd  Vice President of the United States',
#        '5th  United States Secretary of State   (1801 - 1809)',
#        '7th  United States Secretary of State   (1811 - 1817)',
#        '8th  United States Secretary of State   (1817 - 1825)',
#        'U.S. Senator   ( Class 2 )   from  Tennessee   (1823 - 1825)',
#        '8th  Vice President of the United States',
#        'United States Minister to Colombia   (1828 - 1829)',
#        '10th  Vice President of the United States',
#        '9th  Governor of Tennessee   (1839 - 1841)',
#        'Major General  of the  1st Infantry Regiment   United States Army   (1846 - 1849)',
#        '12th  Vice President of the United States',
#        'Brigadier General  of the  9th Infantry   United States Army   (1847 - 1848)',
#        "United States Minister  to the   Court of St James's   (1853 - 1856)",
# ...

# %%
cleaning_df.columns = ['S.NO.', 'PRESIDENT', 'PRESIDENT FIXED', 'PRIOR', 'PARTY', 'VICE', 'VICE FIXED', 'SALARY', 'DATE UPDATED', 'DATE CREATED']

# %%
cleaning_df
# Out:
#     S.NO.               PRESIDENT         PRESIDENT FIXED  \
# 0       1       George Washington       George Washington
# 1       2              john adams              John Adams
# 2       3        Thomas Jefferson        Thomas Jefferson
# 3       4           James Madison           James Madison
# 4       5            JAMES MONROE            James Monroe
# 5       6       John Quincy Adams       John Quincy Adams
# 6       7          Andrew Jackson          Andrew Jackson
# 7       8        Martin Van Buren        Martin Van Buren
# 8       9  William Henry Harrison  William Henry Harrison
# 9      10              john tyler              John Tyler
# 10     11           James K. Polk           James K. Polk
# 11     12          Zachary Taylor          Zachary Taylor
# 12     13        Millard Fillmore        Millard Fillmore
# 13     14         Franklin Pierce         Franklin Pierce
# 14     15          James Buchanan          James Buchanan
# ...

# %%
#changing rows to upper case
cleaning_df = cleaning_df['PRESIDENT'].str.upper()

# %%
cleaning_df
# Out:
# 0          GEORGE WASHINGTON
# 1                 JOHN ADAMS
# 2           THOMAS JEFFERSON
# 3              JAMES MADISON
# 4               JAMES MONROE
# 5          JOHN QUINCY ADAMS
# 6             ANDREW JACKSON
# 7           MARTIN VAN BUREN
# 8     WILLIAM HENRY HARRISON
# 9                 JOHN TYLER
# 10             JAMES K. POLK
# 11            ZACHARY TAYLOR
# 12          MILLARD FILLMORE
# 13           FRANKLIN PIERCE
# 14            JAMES BUCHANAN
# 15           ABRAHAM LINCOLN
# 16            ANDREW JOHNSON
# 17          ULYSSES S. GRANT
# 18       RUTHERFORD B. HAYES
# 19         JAMES A. GARFIELD
# 20         CHESTER A. ARTHUR
# 21          GROVER CLEVELAND
# 22         BENJAMIN HARRISON
# 23          GROVER CLEVELAND
# 24          WILLIAM MCKINLEY
# 25        THEODORE ROOSEVELT
# 26       WILLIAM HOWARD TAFT
# 27            WOODROW WILSON
# 28            WOODROW WILSON
# 29         WARREN G. HARDING
# 30           CALVIN COOLIDGE
# 31            HERBERT HOOVER
# ...
