# %%
dataframe = {
    "name" :["John", "Anna", "peter", "Linda"],
    "Age" : [28, 24, 35, 32],
    "cities" : ["Boston", "Austin", "Denver", "Seattle"],
}

# %%
import pandas as pd

# %%
dataframe_df = pd.DataFrame(dataframe)

# %%
dataframe_df
# Out:
#     name  Age   cities
# 0   John   28   Boston
# 1   Anna   24   Austin
# 2  peter   35   Denver
# 3  Linda   32  Seattle

# %%
dataframe_df.to_csv('dataframe.csv')

# %%
dataframe_df.to_excel('dataframe.xlsx')

# %%
dataframe_df = pd.read_csv('./dataframe.csv')

# %%
dataframe_df
# Out:
#    Unnamed: 0   name  Age   cities
# 0           0   John   28   Boston
# 1           1   Anna   24   Austin
# 2           2  peter   35   Denver
# 3           3  Linda   32  Seattle

# %%
dataframe_df.to_json('dataframe.json')

# %%
student = {
    "name" : ['abiodun', 'anas', 'anisah', 'kenny'],
    "age" : [29, 17, 15, 13],
    "grade" : ['A', 'B', 'A', 'B'],
    "height" : [4.5, 5.5, 4.7, 5.6]
}

student_df = pd.DataFrame(student)

# %%
student_df['Complextion'] = ['dark', 'fair', 'chocolate' , 'fair']

# %%
student_df['age'] = student_df['age'] + 1

# %%
student_df
# Out:
#       name  age grade  height Complextion
# 0  abiodun   30     A     4.5        dark
# 1     anas   18     B     5.5        fair
# 2   anisah   16     A     4.7   chocolate
# 3    kenny   14     B     5.6        fair

# %%
student_df['age'][2] = 18
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11592\3401850894.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   student_df['age'][2] = 18

# %%
student_df["score"] = [80, 65, 50, 90]

# %%
mens_perfume =pd.read_csv('./ebay_mens_perfume.csv')

# %%
mens_perfume
# Out:
#               brand                                              title  \
# 0              Dior  Christian Dior Sauvage Men's EDP 3.4 oz Fragra...
# 1           AS SHOW  A-v-entus Eau de Parfum 3.3 oz 100ML Millesime...
# 2         Unbranded                   HOGO BOSS cologne For Men 3.4 oz
# 3    Giorgio Armani  Acqua Di Gio by Giorgio Armani 6.7 Fl oz Eau D...
# 4           Lattafa  Lattafa Men's Hayaati Al Maleky EDP Spray 3.4 ...
# ..              ...                                                ...
# 995           GUESS  Guess 1981 by Guess cologne for men EDT 3.3 / ...
# 996           Armaf  Club de Nuit Intense by Armaf cologne for men ...
# 997    Paco Rabanne  Invictus by Paco Rabanne for Men EDT Spray 3.4...
# 998          Lomani  Lomani EDT Cologne 3.4 oz Men - Authentic, Bra...
# 999    Estee Lauder  Beyond Paradise by Estee Lauder for Men Cologn...
#
#                 type   price priceWithCurrency  available  \
# ...

# %%
mens_perfume.loc[10]
# Out:
# brand                                                     Ralph Lauren
# title                Polo Blue by Ralph Lauren 4.2 oz EDT Cologne f...
# type                                                   Eau de Toilette
# price                                                            34.99
# priceWithCurrency                                         US $34.99/ea
# available                                                         10.0
# availableText                        More than 10 available / 615 sold
# sold                                                             615.0
# lastUpdated                                  May 24, 2024 07:53:23 PDT
# itemLocation                           Ecorse, Michigan, United States
# Name: 10, dtype: object

# %%
mens_perfume.loc[10:20, ['brand', 'title', 'type']]
# Out:
#                brand                                              title  \
# 10      Ralph Lauren  Polo Blue by Ralph Lauren 4.2 oz EDT Cologne f...
# 11     Dolce&Gabbana  Dolce & Gabbana Light Blue Men 4.2 oz / 125 mL...
# 12          SECERTMU  New 2024 Sexy Cologne Cupid Hypnosis Long Last...
# 13           As Show  Sauvage Eau de Parfum Spray For Men 3.4 Oz/100...
# 14           Versace  Eau Fraiche By Versace 3.4 oz 100 ml Eau de To...
# 15      Paco Rabanne  1 Million by Paco Rabanne 3.4 Fl oz / 100 ml P...
# 16          Grandeur  Tribal Intense by Grandeur - Eau de Parfum for...
# 17             Armaf  Club de Nuit Intense by Armaf 3.6 oz EDT Colog...
# 18  Carolina Herrera  Carolina Herrera 212 NYC Men's Cologne EDT 3.4...
# 19              Dior  Dior Sauvage Eau de Toilette 3.4 Oz 100ml Bran...
# 20   Dolce & Gabbana  Light Blue by Dolce & Gabbana 4.2 oz Cologne f...
#
#                type
# 10  Eau de Toilette
# 11  Eau de Toilette
# 12          Perfume
# ...

# %%
mens_perfume.iloc[10:15, [3,5,7]]
# Out:
#     price  available   sold
# 10  34.99       10.0  615.0
# 11  29.95        7.0  458.0
# 12  15.99       10.0  889.0
# 13  59.99        9.0   63.0
# 14  34.99        7.0  136.0

# %%
mens_perfume.brand
# Out:
# 0                Dior
# 1             AS SHOW
# 2           Unbranded
# 3      Giorgio Armani
# 4             Lattafa
#             ...
# 995             GUESS
# 996             Armaf
# 997      Paco Rabanne
# 998            Lomani
# 999      Estee Lauder
# Name: brand, Length: 1000, dtype: object

# %%
mens_perfume['priceWithCurrency']
# Out:
# 0      US $84.99/ea
# 1        US $109.99
# 2        US $100.00
# 3      US $44.99/ea
# 4         US $16.91
#            ...
# 995    US $20.28/ea
# 996       US $30.58
# 997    US $39.99/ea
# 998     US $9.99/ea
# 999    US $17.49/ea
# Name: priceWithCurrency, Length: 1000, dtype: object

# %%
mens_perfume[['availableText', 'priceWithCurrency','type']]
# Out:
#                              availableText priceWithCurrency             type
# 0        More than 10 available / 116 sold      US $84.99/ea    Eau de Parfum
# 1                    8 available / 48 sold        US $109.99    Eau de Parfum
# 2         More than 10 available / 27 sold        US $100.00  Eau de Toilette
# 3                   2 available / 159 sold      US $44.99/ea  Eau de Toilette
# 4    Limited quantity available / 156 sold         US $16.91       Fragrances
# ..                                     ...               ...              ...
# 995              45 available / 1,613 sold      US $20.28/ea  Eau de Toilette
# 996       More than 10 available / 31 sold         US $30.58  Eau de Toilette
# 997                 2 available / 305 sold      US $39.99/ea  Eau de Toilette
# 998                  2 available / 22 sold       US $9.99/ea  Eau de Toilette
# 999       More than 10 available / 24 sold      US $17.49/ea    Cologne spray
#
# [1000 rows x 3 columns]

# %%
mens_perfume[(mens_perfume['price'] > 100) & (mens_perfume['type'] == 'Eau de Toilette')]
# Out:
#                         brand  \
# 342        Yves Saint Laurent
# 363              Paco Rabanne
# 397  Maison Francis Kurkdjian
# 437        Jean Paul Gaultier
# 461          Carolina Herrera
# 490                 Valentino
# 762              Paco Rabanne
# 822        Jean Paul Gaultier
# 856        Yves Saint Laurent
# 973                Nina Ricci
#
#                                                  title             type  \
# 342  YSL La Nuit De L’Homme Bleu Electrique EDT INT...  Eau de Toilette
# 363  1 Million Lucky by Paco Rabanne 3.4 oz EDT Col...  Eau de Toilette
# 397  Maison Francis Kurkdjian Amyris Homme 2.4oz Ea...  Eau de Toilette
# 437  Jean Paul Gaultier Le Beau 4.2 oz. Eau de Toil...  Eau de Toilette
# 461  CH Men Prive by Carolina Herrera 3.4 oz / 100 ...  Eau de Toilette
# 490  Valentino Uomo Born In Roma Coral Fantasy 3.4 ...  Eau de Toilette
# 762  Paco Rabanne 1 One Million Lucky Eau De Toilet...  Eau de Toilette
# ...

# %%
mens_perfume['Bonaza Percentage'] = mens_perfume['price'] * 0.05
mens_perfume['Bonaza Price'] = mens_perfume['price'] - mens_perfume['Bonaza Percentage']

# %%
mens_perfume
# Out:
#               brand                                              title  \
# 0              Dior  Christian Dior Sauvage Men's EDP 3.4 oz Fragra...
# 1           AS SHOW  A-v-entus Eau de Parfum 3.3 oz 100ML Millesime...
# 2         Unbranded                   HOGO BOSS cologne For Men 3.4 oz
# 3    Giorgio Armani  Acqua Di Gio by Giorgio Armani 6.7 Fl oz Eau D...
# 4           Lattafa  Lattafa Men's Hayaati Al Maleky EDP Spray 3.4 ...
# ..              ...                                                ...
# 995           GUESS  Guess 1981 by Guess cologne for men EDT 3.3 / ...
# 996           Armaf  Club de Nuit Intense by Armaf cologne for men ...
# 997    Paco Rabanne  Invictus by Paco Rabanne for Men EDT Spray 3.4...
# 998          Lomani  Lomani EDT Cologne 3.4 oz Men - Authentic, Bra...
# 999    Estee Lauder  Beyond Paradise by Estee Lauder for Men Cologn...
#
#                 type   price priceWithCurrency  available  \
# ...
