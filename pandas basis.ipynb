# %%
import pandas as pd

# %%
power = [234, 563, 754, 346]

df = pd.DataFrame(power, columns=['power_generated'])

# %%
df
# Out:
#    power_generated
# 0              234
# 1              563
# 2              754
# 3              346

# %%
student = {
    "name" : ['abiodun', 'anas', 'anisah', 'kenny'],
    "age" : [29, 17, 15, 13],
    "grade" : ['A', 'B', 'A', 'B'],
    "height" : [4.5, 5.5, 4.7, 5.6]
}

student_df = pd.DataFrame(student)

# %%
student_df
# Out:
#       name  age grade  height
# 0  abiodun   29     A     4.5
# 1     anas   17     B     5.5
# 2   anisah   15     A     4.7
# 3    kenny   13     B     5.6

# %%
mens_perfume = pd.read_csv('./ebay_mens_perfume.csv')

# %%
mens_perfume
# Out:
#               brand                                              title  \
# 0              Dior  Christian Dior Sauvage Men's EDP 3.4 oz Fragra...
# 1           AS SHOW  A-v-entus Eau de Parfum 3.3 oz 100ML Millesime...
# 2         Unbranded                   HOGO BOSS cologne For Men 3.4 oz
# 3    Giorgio Armani  Acqua Di Gio by Giorgio Armani 6.7 Fl oz Eau D...
# 4           Lattafa  Lattafa Men's Hayaati Al Maleky EDP Spray 3.4 ...
# ..              ...                                                ...
# 995           GUESS  Guess 1981 by Guess cologne for men EDT 3.3 / ...
# 996           Armaf  Club de Nuit Intense by Armaf cologne for men ...
# 997    Paco Rabanne  Invictus by Paco Rabanne for Men EDT Spray 3.4...
# 998          Lomani  Lomani EDT Cologne 3.4 oz Men - Authentic, Bra...
# 999    Estee Lauder  Beyond Paradise by Estee Lauder for Men Cologn...
#
#                 type   price priceWithCurrency  available  \
# ...

# %%
superstore = pd.read_excel("./Superstore pivot class.xlsx")

# %%
superstore
# Out:
#           Unnamed: 0 Unnamed: 1
# 0                NaN        NaN
# 1        Total Sales        NaN
# 2        710137.0714        NaN
# 3                NaN        NaN
# 4                NaN        NaN
# ..               ...        ...
# 85        Paul Prost         34
# 86       Seth Vernon         32
# 87     William Brown         37
# 88  Zuschuss Carroll         31
# 89       Grand Total        360
#
# [90 rows x 2 columns]

# %%
bad_structured = pd.read_excel('./1.-Badly-Structured-Sales-Data-1.xlsx')

# %%
bad_structured
# Out:
#           Segment>>     Consumer Unnamed: 2    Unnamed: 3      Unnamed: 4  \
# 0       Ship Mode>>  First Class   Same Day  Second Class  Standard Class
# 1          Order ID          NaN        NaN           NaN             NaN
# 2    CA-2011-100293          NaN        NaN           NaN             NaN
# 3    CA-2011-100706          NaN        NaN        129.44             NaN
# 4    CA-2011-100895          NaN        NaN           NaN          605.47
# ..              ...          ...        ...           ...             ...
# 814  US-2014-166611          NaN        NaN           NaN             NaN
# 815  US-2014-167920          NaN        NaN       1827.51             NaN
# 816  US-2014-168116          NaN        NaN           NaN             NaN
# 817  US-2014-168690          NaN        NaN           NaN           2.808
# 818     Grand Total    20802.173   8132.409    49724.2545     116922.1345
#
#      Consumer Total    Corporate Unnamed: 7    Unnamed: 8      Unnamed: 9  \
# ...

# %%
student_df.to_csv('student.csv')

# %%
student_df.to_excel('student.xlsx')
